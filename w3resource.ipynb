# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinitladse/gitbashhh/blob/main/w3resource.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#SET
## set is unordered and not indexing
# Out:
# w3resource.com
# 14

# %%
my_list = [1,1,25,5,6,9,8,75,4,2,5]
vinit = set(my_list)
vinit
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-5664f9045dce> in <module>
#       1 my_list = [1,1,25,5,6,9,8,75,4,2,5]
# ----> 2 vinit = set(my_list)
#       3 vinit
#
# TypeError: 'set' object is not callable

# %%
nayan = ['vinit', 'raj', 1,2,5,6,4,5,6]
vinit = set(nayan)
vinit
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-d3dc5c754bc7> in <module>
#       1 nayan = ['vinit', 'raj', 1,2,5,6,4,5,6]
# ----> 2 vinit = set(nayan)
#       3 vinit
#
# TypeError: 'set' object is not callable

# %%
vinit = 

print(vinit)
type(vinit)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-cdd584bcfbf1> in <module>
# ----> 1 vinit = set([1,2,4])
#       2
#       3 print(vinit)
#       4 type(vinit)
#
# TypeError: 'set' object is not callable
